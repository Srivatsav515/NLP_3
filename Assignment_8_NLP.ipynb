# %% [markdown]
# <a href="https://colab.research.google.com/github/Srivatsav515/NLP_3/blob/main/Assignment_8_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

text = """Once upon a time, there was a little girl named Red Riding Hood. She loved to visit her grandmother, who lived in the woods. One day, her mother asked her to take a basket of goodies to her grandmother. On her way through the woods, she met a big bad wolf who wanted to eat her."""

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for i in range(1, len(tokenizer.texts_to_sequences([text])[0])):
    n_gram_sequence = tokenizer.texts_to_sequences([text])[0][:i+1]
    input_sequences.append(n_gram_sequence)

max_seq_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_seq_len, padding='pre'))

X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

def transformer_block(vocab_size, seq_len):
    inputs = tf.keras.layers.Input(shape=(seq_len,))
    embedding = tf.keras.layers.Embedding(vocab_size, 64)(inputs)

    attention_output = tf.keras.layers.MultiHeadAttention(num_heads=2, key_dim=64)(embedding, embedding)
    attention_output = tf.keras.layers.LayerNormalization()(attention_output + embedding)

    ff_output = tf.keras.layers.Dense(128, activation='relu')(attention_output)
    ff_output = tf.keras.layers.Dense(64)(ff_output)
    ff_output = tf.keras.layers.LayerNormalization()(ff_output + attention_output)

    outputs = tf.keras.layers.GlobalAveragePooling1D()(ff_output)
    outputs = tf.keras.layers.Dense(vocab_size, activation='softmax')(outputs)

    model = tf.keras.models.Model(inputs, outputs)
    return model

model = transformer_block(total_words, max_seq_len-1)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

epochs_list = [20, 60, 70]
history = []
for epoch in epochs_list:
    print(f"Training with {epoch} epochs...")
    h = model.fit(X, y, epochs=epoch, verbose=1)
    history.append(h)

def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted_word_index = np.argmax(predicted, axis=1)
        output_word = tokenizer.index_word[predicted_word_index[0]]
        seed_text += " " + output_word
    return seed_text

seed_text = "Once upon a time"
generated_text = generate_text(seed_text, 50, model, max_seq_len)
print("Generated text:", generated_text)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 55)]                 0         []
#
#  embedding (Embedding)       (None, 55, 64)               2624      ['input_1[0][0]']
#
#  multi_head_attention (Mult  (None, 55, 64)               33216     ['embedding[0][0]',
#  iHeadAttention)                                                     'embedding[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 55, 64)               0         ['multi_head_attention[0][0]',
#  Lambda)                                                             'embedding[0][0]']
#
#  layer_normalization (Layer  (None, 55, 64)               128       ['tf.__operators__.add[0][0]']
#  Normalization)
#
#  dense (Dense)               (None, 55, 128)              8320      ['layer_normalization[0][0]']
#
#  dense_1 (Dense)             (None, 55, 64)               8256      ['dense[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 55, 64)               0         ['dense_1[0][0]',
#  OpLambda)                                                           'layer_normalization[0][0]']
#
#  layer_normalization_1 (Lay  (None, 55, 64)               128       ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  global_average_pooling1d (  (None, 64)                   0         ['layer_normalization_1[0][0]'
#  GlobalAveragePooling1D)                                            ]
#
#  dense_2 (Dense)             (None, 41)                   2665      ['global_average_pooling1d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params:
60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9944 - accuracy: 0.1273
# Epoch 8/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.9776 - accuracy: 0.1455
# Epoch 9/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9626 - accuracy: 0.1455
# Epoch 10/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9502 - accuracy: 0.1455
# Epoch 11/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.9343 - accuracy: 0.1455
# Epoch 12/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9176 - accuracy: 0.1636
# Epoch 13/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.9069 - accuracy: 0.1455
# Epoch 14/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8954 - accuracy: 0.1455
# Epoch 15/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8844 - accuracy: 0.1455
# Epoch 16/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8702 - accuracy: 0.1455
# Epoch 17/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8544 - accuracy: 0.1455
# Epoch 18/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8389 - accuracy: 0.1455
# Epoch 19/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.8398 - accuracy: 0.1455
# Epoch 20/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.8166 - accuracy: 0.1455
# Epoch 21/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.8046 - accuracy: 0.1455
# Epoch 22/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7855 - accuracy: 0.1455
# Epoch 23/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7810 - accuracy: 0.1455
# Epoch 24/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7645 - accuracy: 0.1455
# Epoch 25/60
# 2/2 [==============================] - 0s 25ms/step - loss: 2.7578 - accuracy: 0.1455
# Epoch 26/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.7481 - accuracy: 0.1455
# Epoch 27/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7339 - accuracy: 0.1455
# Epoch 28/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.7232 - accuracy: 0.1818
# Epoch 29/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.7087 - accuracy: 0.1455
# Epoch 30/60
# 2/2 [==============================] - 0s 25ms/step - loss: 2.6954 - accuracy: 0.1636
# Epoch 31/60
# 2/2 [==============================] - 0s 23ms/step - loss: 2.6895 - accuracy: 0.1636
# Epoch 32/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6735 - accuracy: 0.1636
# Epoch 33/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6629 - accuracy: 0.1818
# Epoch 34/60
# 2/2 [==============================] - 0s 24ms/step - loss: 2.6553 - accuracy: 0.1636
# Epoch 35/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.6398 - accuracy: 0.1636
# Epoch 36/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.6330 - accuracy: 0.2000
# Epoch 37/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.6187 - accuracy: 0.1818
# Epoch 38/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.6009 - accuracy: 0.2000
# Epoch 39/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5967 - accuracy: 0.1636
# Epoch 40/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.5871 - accuracy: 0.1818
# Epoch 41/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5805 - accuracy: 0.2000
# Epoch 42/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5724 - accuracy: 0.1818
# Epoch 43/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5565 - accuracy: 0.1455
# Epoch 44/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5427 - accuracy: 0.2364
# Epoch 45/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5386 - accuracy: 0.2182
# Epoch 46/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.5163 - accuracy: 0.2182
# Epoch 47/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.5055 - accuracy: 0.1818
# Epoch 48/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4949 - accuracy: 0.2000
# Epoch 49/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4855 - accuracy: 0.2000
# Epoch 50/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4755 - accuracy: 0.2182
# Epoch 51/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4659 - accuracy: 0.2545
# Epoch 52/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4543 - accuracy: 0.2364
# Epoch 53/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.4554 - accuracy: 0.1818
# Epoch 54/60
# 2/2 [==============================] - 0s 22ms/step - loss: 2.4239 - accuracy: 0.1818
# Epoch 55/60
# 2/2 [==============================] - 0s 20ms/step - loss: 2.4115 - accuracy: 0.2364
# Epoch 56/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3957 - accuracy: 0.1818
# Epoch 57/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3843 - accuracy: 0.1636
# Epoch 58/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3818 - accuracy: 0.2000
# Epoch 59/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3670 - accuracy: 0.2182
# Epoch 60/60
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3444 - accuracy: 0.2727
# Training with 70 epochs...
# Epoch 1/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.3335 - accuracy: 0.2545
# Epoch 2/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.3308 - accuracy: 0.2364
# Epoch 3/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.3157 - accuracy: 0.2364
# Epoch 4/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2945 - accuracy: 0.2909
# Epoch 5/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2904 - accuracy: 0.2545
# Epoch 6/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.2655 - accuracy: 0.2727
# Epoch 7/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2555 - accuracy: 0.2364
# Epoch 8/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2581 - accuracy: 0.2364
# Epoch 9/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2212 - accuracy: 0.2364
# Epoch 10/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2340 - accuracy: 0.2545
# Epoch 11/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.2065 - accuracy: 0.2909
# Epoch 12/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1794 - accuracy: 0.2727
# Epoch 13/70
# 2/2 [==============================] - 0s 20ms/step - loss: 2.1981 - accuracy: 0.2545
# Epoch 14/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1553 - accuracy: 0.3273
# Epoch 15/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.1644 - accuracy: 0.3091
# Epoch 16/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1313 - accuracy: 0.2909
# Epoch 17/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1358 - accuracy: 0.2545
# Epoch 18/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.1076 - accuracy: 0.3091
# Epoch 19/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0936 - accuracy: 0.2727
# Epoch 20/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0971 - accuracy: 0.2545
# Epoch 21/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0552 - accuracy: 0.3273
# Epoch 22/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0538 - accuracy: 0.3455
# Epoch 23/70
# 2/2 [==============================] - 0s 21ms/step - loss: 2.0360 - accuracy: 0.3636
# Epoch 24/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0013 - accuracy: 0.4000
# Epoch 25/70
# 2/2 [==============================] - 0s 22ms/step - loss: 2.0066 - accuracy: 0.3273
# Epoch 26/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9870 - accuracy: 0.2727
# Epoch 27/70
# 2/2 [==============================] - 0s 23ms/step - loss: 1.9488 - accuracy: 0.4000
# Epoch 28/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9481 - accuracy: 0.3455
# Epoch 29/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.9519 - accuracy: 0.3818
# Epoch 30/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9667 - accuracy: 0.3091
# Epoch 31/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8781 - accuracy: 0.4545
# Epoch 32/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.9227 - accuracy: 0.3818
# Epoch 33/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8852 - accuracy: 0.4364
# Epoch 34/70
# 2/2 [==============================] - 0s 23ms/step - loss: 1.8650 - accuracy: 0.3273
# Epoch 35/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.8446 - accuracy: 0.3818
# Epoch 36/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7891 - accuracy: 0.4000
# Epoch 37/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8103 - accuracy: 0.4364
# Epoch 38/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.8006 - accuracy: 0.4364
# Epoch 39/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7932 - accuracy: 0.4727
# Epoch 40/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.7526 - accuracy: 0.4182
# Epoch 41/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7184 - accuracy: 0.4182
# Epoch 42/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.7190 - accuracy: 0.4364
# Epoch 43/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6931 - accuracy: 0.4545
# Epoch 44/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6750 - accuracy: 0.4182
# Epoch 45/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.6454 - accuracy: 0.4727
# Epoch 46/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.6409 - accuracy: 0.4545
# Epoch 47/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.6438 - accuracy: 0.4909
# Epoch 48/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5918 - accuracy: 0.5273
# Epoch 49/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5749 - accuracy: 0.5636
# Epoch 50/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5600 - accuracy: 0.5273
# Epoch 51/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5484 - accuracy: 0.5455
# Epoch 52/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.5199 - accuracy: 0.6182
# Epoch 53/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.5242 - accuracy: 0.5818
# Epoch 54/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4788 - accuracy: 0.6545
# Epoch 55/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4732 - accuracy: 0.4727
# Epoch 56/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4572 - accuracy: 0.5455
# Epoch 57/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4444 - accuracy: 0.6364
# Epoch 58/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4238 - accuracy: 0.5636
# Epoch 59/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.4181 - accuracy: 0.5818
# Epoch 60/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3793 - accuracy: 0.6545
# Epoch 61/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.4124 - accuracy: 0.6182
# Epoch 62/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3658 - accuracy: 0.6364
# Epoch 63/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.3487 - accuracy: 0.6727
# Epoch 64/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3445 - accuracy: 0.6364
# Epoch 65/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.3528 - accuracy: 0.6182
# Epoch 66/70
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3114 - accuracy: 0.6727
# Epoch 67/70
# 2/2 [==============================] - 0s 22ms/step - loss: 1.2993 - accuracy: 0.7273
# Epoch 68/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2680 - accuracy: 0.6909
# Epoch 69/70
# 2/2 [==============================] - 0s 21ms/step - loss: 1.2674 - accuracy: 0.6545
# Epoch 70/70
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2821 - accuracy: 0.6545
# Generated text: Once upon a time a a little girl named red hood hood loved to visit her grandmother who lived lived woods one one her day her her take a basket of goodies her goodies her grandmother grandmother grandmother the the woods to to way through woods she she she a met a big bad
